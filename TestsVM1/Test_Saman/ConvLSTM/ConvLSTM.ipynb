# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score
from tensorflow.keras import Input

import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# === CALLBACK pour suivre les poids ===
class WeightLogger(Callback):
    def __init__(self, layer_name="lstm"):
        super().__init__()
        self.layer_name = layer_name
        self.weights_per_epoch = []

    def on_epoch_end(self, epoch, logs=None):
        for layer in self.model.layers:
            if self.layer_name in layer.name.lower():
                weights = layer.get_weights()[0]
                self.weights_per_epoch.append(weights.copy())
                break

# === 1. Chargement des données ===
def load_data(csv_path, ws):
    df = pd.read_csv(csv_path)
    scaler = MinMaxScaler()
    scaled_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
    y_scaled = scaled_df['production']
    X_scaled = scaled_df.drop(columns=['production'])

    def create_sequences(X, y, window_size=21):
        Xs, ys = [], []
        for i in range(len(X) - window_size):
            Xs.append(X[i:i + window_size])
            ys.append(y[i + window_size])
        return np.array(Xs), np.array(ys)

    X_seq, y_seq = create_sequences(X_scaled, y_scaled, ws)
    return X_seq, y_seq, scaler, scaled_df

# === 2. Model ConvLSTM1D ===
def model_convlstm1d(X_seq, y_seq, epoch, batch_sizes):
    X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        Conv1D(filters=128, kernel_size=5, activation='relu', padding='same'),
        LSTM(64, return_sequences=False),
        Dense(32, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer=Adam(0.001), loss='mae')

    weight_logger = WeightLogger(layer_name="lstm")

    history = model.fit(
        X_train, y_train,
        epochs=epoch,
        batch_size=batch_sizes,
        validation_split=0.1,
        verbose=1,
        callbacks=[weight_logger]
    )

    y_pred = model.predict(X_test).flatten()

    return model, history, y_pred, y_test, weight_logger

# === 3. Performance model ===
def plot_function(scaled_data, y_pred, y_test, scaler, weight_logger, history):
    n_features = scaled_data.shape[1]
    dummy = np.zeros((len(y_pred), n_features))
    target_idx = scaled_data.columns.get_loc('production')
    dummy[:, target_idx] = y_pred
    y_pred_real = scaler.inverse_transform(dummy)[:, target_idx]

    dummy_test = np.zeros((len(y_test), n_features))
    dummy_test[:, target_idx] = y_test
    y_test_real = scaler.inverse_transform(dummy_test)[:, target_idx]

    mae = mean_absolute_error(y_test_real, y_pred_real)
    mse = np.mean((y_test_real - y_pred_real) ** 2)
    r2 = r2_score(y_test_real, y_pred_real)

    w00 = [w[0, 0] for w in weight_logger.weights_per_epoch]
    plt.figure(figsize=(8, 4))
    plt.plot(w00)
    plt.xlabel("Époque")
    plt.ylabel("Valeur du poids [0,0]")
    plt.title("Évolution du poids (entrée 0 → cellule 0) dans la couche LSTM")
    plt.grid(True)
    plt.show()

    plt.figure(figsize=(10, 4))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Courbe de Loss (MAE) par époque')
    plt.xlabel('Époque')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(10, 6))
    plt.plot(y_test_real, label="Vrai")
    plt.plot(y_pred_real, label="Prévu")
    plt.legend()
    plt.title(f"Conv1D + LSTM - MAE: {mae:.4f} | R²: {r2:.4f} | MSE: {mse:.4f}")
    plt.show()

    plt.figure(figsize=(6, 6))
    plt.scatter(y_test_real, y_pred_real, alpha=0.7, color='orange')
    plt.plot([min(y_test_real), max(y_test_real)], [min(y_test_real), max(y_test_real)], 'r--', label="Idéal (y = ŷ)")
    plt.xlabel("Valeurs réelles (y)")
    plt.ylabel("Prédictions (ŷ)")
    plt.title("Prédictions vs Réel")
    plt.legend()
    plt.grid(True)
    plt.show()

    return mae, mse, r2, y_test_real, y_pred_real

# === 4. Main ===
def main():
    csv_path = "scaled_dataset.csv"
    window_size = 21
    X_seq, y_seq, scaler, scaled_data = load_data(csv_path, window_size)
    model, history, y_pred, y_test, weight_logger = model_convlstm1d(X_seq, y_seq, epoch=700, batch_sizes=32)
    mae, mse, r2, y_test_real, y_pred_real = plot_function(scaled_data, y_pred, y_test, scaler, weight_logger, history)
    print(f"MAE: {mae:.4f}, MSE: {mse:.4f}, R²: {r2:.4f}")

    StatsDf = pd.DataFrame({
        "Y_test": y_test_real,
        "Y_pred": y_pred_real,
        "Error": y_test_real - y_pred_real,
        "Error_Percent": abs(y_test_real - y_pred_real) / y_test_real * 100
    })

    print(StatsDf.describe())
    StatsDf['Error'].hist(bins=100)
    plt.title("Distribution de l'erreur")
    plt.xlabel("Erreur absolue")
    plt.ylabel("Fréquence")
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# 2025-06-16 14:29:21.837638: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-16 14:29:21.889873: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-16 14:29:23.353965: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Epoch 1/700
# 2025-06-16 14:29:24.424344: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-06-16 14:29:24.424384: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:160] env: CUDA_VISIBLE_DEVICES="-1"
# 2025-06-16 14:29:24.424389: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# 2025-06-16 14:29:24.424393: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-06-16 14:29:24.424397: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: ST-RECH-BLOC
# 2025-06-16 14:29:24.424400: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] hostname: ST-RECH-BLOC
# 2025-06-16 14:29:24.424535: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] libcuda reported version is: 535.247.1
# 2025-06-16 14:29:24.424552: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:194] kernel reported version is: 535.247.1
# 2025-06-16 14:29:24.424555: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:284] kernel version seems to match DSO: 535.247.1
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0406 - val_loss: 0.0388
# Epoch 2/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0365 - val_loss: 0.0368
# Epoch 3/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0366 - val_loss: 0.0441
# Epoch 4/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0361 - val_loss: 0.0358
# Epoch 5/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0343 - val_loss: 0.0374
# Epoch 6/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0356 - val_loss: 0.0367
# Epoch 7/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0338 - val_loss: 0.0368
# Epoch 8/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0331 - val_loss: 0.0356
# Epoch 9/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0333 - val_loss: 0.0356
# Epoch 10/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0329 - val_loss: 0.0372
# Epoch 11/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0329 - val_loss: 0.0383
# Epoch 12/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0328 - val_loss: 0.0385
# Epoch 13/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0326 - val_loss: 0.0347
# Epoch 14/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0325 - val_loss: 0.0344
# Epoch 15/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0322 - val_loss: 0.0367
# Epoch 16/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0319 - val_loss: 0.0344
# Epoch 17/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0320 - val_loss: 0.0364
# Epoch 18/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0318 - val_loss: 0.0376
# Epoch 19/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0321 - val_loss: 0.0339
# Epoch 20/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0311 - val_loss: 0.0347
# Epoch 21/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0313 - val_loss: 0.0339
# Epoch 22/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0311 - val_loss: 0.0365
# Epoch 23/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0309 - val_loss: 0.0335
# Epoch 24/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0306 - val_loss: 0.0336
# Epoch 25/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0302 - val_loss: 0.0335
# Epoch 26/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0302 - val_loss: 0.0358
# Epoch 27/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0305 - val_loss: 0.0337
# Epoch 28/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0301 - val_loss: 0.0334
# Epoch 29/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0303 - val_loss: 0.0347
# Epoch 30/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0299 - val_loss: 0.0332
# Epoch 31/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0296 - val_loss: 0.0334
# Epoch 32/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0295 - val_loss: 0.0326
# Epoch 33/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0299 - val_loss: 0.0338
# Epoch 34/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0293 - val_loss: 0.0330
# Epoch 35/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0292 - val_loss: 0.0322
# Epoch 36/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0295 - val_loss: 0.0332
# Epoch 37/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0288 - val_loss: 0.0324
# Epoch 38/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0296 - val_loss: 0.0323
# Epoch 39/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0285 - val_loss: 0.0324
# Epoch 40/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0285 - val_loss: 0.0318
# Epoch 41/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0280 - val_loss: 0.0329
# Epoch 42/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0280 - val_loss: 0.0315
# Epoch 43/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0280 - val_loss: 0.0323
# Epoch 44/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0275 - val_loss: 0.0325
# Epoch 45/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0276 - val_loss: 0.0316
# Epoch 46/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0274 - val_loss: 0.0320
# Epoch 47/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0297 - val_loss: 0.0318
# Epoch 48/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0271 - val_loss: 0.0306
# Epoch 49/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0266 - val_loss: 0.0316
# Epoch 50/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0263 - val_loss: 0.0315
# Epoch 51/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0264 - val_loss: 0.0323
# Epoch 52/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0260 - val_loss: 0.0304
# Epoch 53/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0260 - val_loss: 0.0301
# Epoch 54/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0258 - val_loss: 0.0315
# Epoch 55/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0254 - val_loss: 0.0312
# Epoch 56/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0255 - val_loss: 0.0323
# Epoch 57/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0248 - val_loss: 0.0322
# Epoch 58/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0250 - val_loss: 0.0307
# Epoch 59/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0246 - val_loss: 0.0310
# Epoch 60/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0243 - val_loss: 0.0300
# Epoch 61/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0242 - val_loss: 0.0309
# Epoch 62/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0239 - val_loss: 0.0311
# Epoch 63/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0232 - val_loss: 0.0306
# Epoch 64/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0238 - val_loss: 0.0295
# Epoch 65/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0241 - val_loss: 0.0292
# Epoch 66/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0229 - val_loss: 0.0293
# Epoch 67/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0228 - val_loss: 0.0293
# Epoch 68/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0226 - val_loss: 0.0302
# Epoch 69/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0222 - val_loss: 0.0352
# Epoch 70/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0237 - val_loss: 0.0291
# Epoch 71/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0226 - val_loss: 0.0291
# Epoch 72/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0218 - val_loss: 0.0287
# Epoch 73/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0215 - val_loss: 0.0305
# Epoch 74/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0213 - val_loss: 0.0285
# Epoch 75/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0212 - val_loss: 0.0301
# Epoch 76/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0207 - val_loss: 0.0288
# Epoch 77/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0203 - val_loss: 0.0311
# Epoch 78/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0206 - val_loss: 0.0295
# Epoch 79/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0203 - val_loss: 0.0287
# Epoch 80/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0199 - val_loss: 0.0289
# Epoch 81/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0198 - val_loss: 0.0276
# Epoch 82/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0195 - val_loss: 0.0309
# Epoch 83/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0195 - val_loss: 0.0280
# Epoch 84/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0195 - val_loss: 0.0278
# Epoch 85/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0191 - val_loss: 0.0281
# Epoch 86/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0194 - val_loss: 0.0273
# Epoch 87/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0182 - val_loss: 0.0284
# Epoch 88/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0187 - val_loss: 0.0297
# Epoch 89/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0249 - val_loss: 0.0290
# Epoch 90/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0211 - val_loss: 0.0291
# Epoch 91/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0182 - val_loss: 0.0283
# Epoch 92/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0181 - val_loss: 0.0279
# Epoch 93/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0175 - val_loss: 0.0290
# Epoch 94/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - loss: 0.0176 - val_loss: 0.0285
# Epoch 95/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - loss: 0.0191 - val_loss: 0.0274
# Epoch 96/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0174 - val_loss: 0.0275
# Epoch 97/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0172 - val_loss: 0.0287
# Epoch 98/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0167 - val_loss: 0.0276
# Epoch 99/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0169 - val_loss: 0.0313
# Epoch 100/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0175 - val_loss: 0.0270
# Epoch 101/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0184 - val_loss: 0.0272
# Epoch 102/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0175 - val_loss: 0.0270
# Epoch 103/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0163 - val_loss: 0.0269
# Epoch 104/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0162 - val_loss: 0.0274
# Epoch 105/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0161 - val_loss: 0.0269
# Epoch 106/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0158 - val_loss: 0.0266
# Epoch 107/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0158 - val_loss: 0.0267
# Epoch 108/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0155 - val_loss: 0.0268
# Epoch 109/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0155 - val_loss: 0.0266
# Epoch 110/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0153 - val_loss: 0.0265
# Epoch 111/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0152 - val_loss: 0.0272
# Epoch 112/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0156 - val_loss: 0.0287
# Epoch 113/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0165 - val_loss: 0.0268
# Epoch 114/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0153 - val_loss: 0.0264
# Epoch 115/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0149 - val_loss: 0.0268
# Epoch 116/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0147 - val_loss: 0.0266
# Epoch 117/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0147 - val_loss: 0.0273
# Epoch 118/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0146 - val_loss: 0.0263
# Epoch 119/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0145 - val_loss: 0.0267
# Epoch 120/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0146 - val_loss: 0.0270
# Epoch 121/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0151 - val_loss: 0.0252
# Epoch 122/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0179 - val_loss: 0.0256
# Epoch 123/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0148 - val_loss: 0.0256
# Epoch 124/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0140 - val_loss: 0.0249
# Epoch 125/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0140 - val_loss: 0.0265
# Epoch 126/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0140 - val_loss: 0.0257
# Epoch 127/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0139 - val_loss: 0.0260
# Epoch 128/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0139 - val_loss: 0.0252
# Epoch 129/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0136 - val_loss: 0.0251
# Epoch 130/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0134 - val_loss: 0.0256
# Epoch 131/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0138 - val_loss: 0.0259
# Epoch 132/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0136 - val_loss: 0.0263
# Epoch 133/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0136 - val_loss: 0.0254
# Epoch 134/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0149 - val_loss: 0.0263
# Epoch 135/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0138 - val_loss: 0.0268
# Epoch 136/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - loss: 0.0132 - val_loss: 0.0258
# Epoch 137/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - loss: 0.0130 - val_loss: 0.0256
# Epoch 138/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0131 - val_loss: 0.0258
# Epoch 139/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0134 - val_loss: 0.0265
# Epoch 140/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0131 - val_loss: 0.0254
# Epoch 141/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0128 - val_loss: 0.0248
# Epoch 142/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0128 - val_loss: 0.0257
# Epoch 143/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0131 - val_loss: 0.0253
# Epoch 144/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0127 - val_loss: 0.0273
# Epoch 145/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0130 - val_loss: 0.0249
# Epoch 146/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0126 - val_loss: 0.0255
# Epoch 147/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0126 - val_loss: 0.0244
# Epoch 148/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0126 - val_loss: 0.0257
# Epoch 149/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0126 - val_loss: 0.0252
# Epoch 150/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0126 - val_loss: 0.0249
# Epoch 151/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0129 - val_loss: 0.0244
# Epoch 152/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0123 - val_loss: 0.0256
# Epoch 153/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0125 - val_loss: 0.0248
# Epoch 154/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0123 - val_loss: 0.0259
# Epoch 155/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0124 - val_loss: 0.0251
# Epoch 156/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0121 - val_loss: 0.0252
# Epoch 157/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0120 - val_loss: 0.0244
# Epoch 158/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0120 - val_loss: 0.0248
# Epoch 159/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0122 - val_loss: 0.0254
# Epoch 160/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0120 - val_loss: 0.0259
# Epoch 161/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0118 - val_loss: 0.0244
# Epoch 162/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0117 - val_loss: 0.0246
# Epoch 163/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0119 - val_loss: 0.0249
# Epoch 164/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0118 - val_loss: 0.0256
# Epoch 165/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0118 - val_loss: 0.0251
# Epoch 166/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0118 - val_loss: 0.0241
# Epoch 167/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0117 - val_loss: 0.0249
# Epoch 168/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0117 - val_loss: 0.0243
# Epoch 169/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0116 - val_loss: 0.0241
# Epoch 170/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0113 - val_loss: 0.0261
# Epoch 171/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0139 - val_loss: 0.0247
# Epoch 172/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0114 - val_loss: 0.0250
# Epoch 173/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0115 - val_loss: 0.0250
# Epoch 174/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0113 - val_loss: 0.0256
# Epoch 175/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0114 - val_loss: 0.0244
# Epoch 176/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0118 - val_loss: 0.0256
# Epoch 177/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0115 - val_loss: 0.0244
# Epoch 178/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0113 - val_loss: 0.0252
# Epoch 179/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0111 - val_loss: 0.0252
# Epoch 180/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0127 - val_loss: 0.0255
# Epoch 181/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0113 - val_loss: 0.0250
# Epoch 182/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0111 - val_loss: 0.0248
# Epoch 183/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0119 - val_loss: 0.0255
# Epoch 184/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0113 - val_loss: 0.0247
# Epoch 185/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0110 - val_loss: 0.0261
# Epoch 186/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0112 - val_loss: 0.0244
# Epoch 187/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0117 - val_loss: 0.0240
# Epoch 188/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0123 - val_loss: 0.0239
# Epoch 189/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0112 - val_loss: 0.0242
# Epoch 190/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0111 - val_loss: 0.0245
# Epoch 191/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0110 - val_loss: 0.0261
# Epoch 192/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0109 - val_loss: 0.0240
# Epoch 193/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0109 - val_loss: 0.0239
# Epoch 194/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0108 - val_loss: 0.0242
# Epoch 195/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0108 - val_loss: 0.0235
# Epoch 196/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0108 - val_loss: 0.0241
# Epoch 197/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0110 - val_loss: 0.0237
# Epoch 198/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0124 - val_loss: 0.0255
# Epoch 199/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0108 - val_loss: 0.0245
# Epoch 200/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0105 - val_loss: 0.0241
# Epoch 201/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0107 - val_loss: 0.0245
# Epoch 202/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0107 - val_loss: 0.0241
# Epoch 203/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0114 - val_loss: 0.0244
# Epoch 204/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0105 - val_loss: 0.0246
# Epoch 205/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0106 - val_loss: 0.0250
# Epoch 206/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0107 - val_loss: 0.0242
# Epoch 207/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0106 - val_loss: 0.0241
# Epoch 208/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0106 - val_loss: 0.0243
# Epoch 209/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0104 - val_loss: 0.0241
# Epoch 210/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0104 - val_loss: 0.0252
# Epoch 211/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0118 - val_loss: 0.0240
# Epoch 212/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0105 - val_loss: 0.0236
# Epoch 213/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0104 - val_loss: 0.0243
# Epoch 214/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0105 - val_loss: 0.0249
# Epoch 215/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0105 - val_loss: 0.0245
# Epoch 216/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0103 - val_loss: 0.0256
# Epoch 217/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0116 - val_loss: 0.0252
# Epoch 218/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0105 - val_loss: 0.0243
# Epoch 219/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0102 - val_loss: 0.0240
# Epoch 220/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0104 - val_loss: 0.0243
# Epoch 221/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0103 - val_loss: 0.0243
# Epoch 222/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0104 - val_loss: 0.0242
# Epoch 223/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0103 - val_loss: 0.0240
# Epoch 224/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0104 - val_loss: 0.0243
# Epoch 225/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0103 - val_loss: 0.0242
# Epoch 226/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0103 - val_loss: 0.0254
# Epoch 227/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0104 - val_loss: 0.0245
# Epoch 228/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0102 - val_loss: 0.0247
# Epoch 229/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0104 - val_loss: 0.0245
# Epoch 230/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 0.0100 - val_loss: 0.0246
# Epoch 231/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0101 - val_loss: 0.0248
# Epoch 232/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0103 - val_loss: 0.0247
# Epoch 233/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0102 - val_loss: 0.0239
# Epoch 234/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0102 - val_loss: 0.0251
# Epoch 235/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0099 - val_loss: 0.0248
# Epoch 236/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 0.0112 - val_loss: 0.0244
# Epoch 237/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0104 - val_loss: 0.0244
# Epoch 238/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0100 - val_loss: 0.0243
# Epoch 239/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0099 - val_loss: 0.0243
# Epoch 240/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0101 - val_loss: 0.0261
# Epoch 241/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0101 - val_loss: 0.0239
# Epoch 242/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0101 - val_loss: 0.0245
# Epoch 243/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0102 - val_loss: 0.0245
# Epoch 244/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0101 - val_loss: 0.0255
# Epoch 245/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0100 - val_loss: 0.0244
# Epoch 246/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0107 - val_loss: 0.0252
# Epoch 247/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0100 - val_loss: 0.0244
# Epoch 248/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0100 - val_loss: 0.0249
# Epoch 249/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0100 - val_loss: 0.0240
# Epoch 250/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0098 - val_loss: 0.0237
# Epoch 251/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0099 - val_loss: 0.0243
# Epoch 252/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0098 - val_loss: 0.0245
# Epoch 253/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0101 - val_loss: 0.0251
# Epoch 254/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0098 - val_loss: 0.0239
# Epoch 255/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0106 - val_loss: 0.0238
# Epoch 256/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0097 - val_loss: 0.0241
# Epoch 257/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0104 - val_loss: 0.0243
# Epoch 258/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0097 - val_loss: 0.0244
# Epoch 259/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0097 - val_loss: 0.0237
# Epoch 260/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0097 - val_loss: 0.0242
# Epoch 261/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0097 - val_loss: 0.0237
# Epoch 262/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - loss: 0.0097 - val_loss: 0.0251
# Epoch 263/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - loss: 0.0096 - val_loss: 0.0241
# Epoch 264/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0096 - val_loss: 0.0248
# Epoch 265/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - loss: 0.0097 - val_loss: 0.0241
# Epoch 266/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0095 - val_loss: 0.0239
# Epoch 267/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0098 - val_loss: 0.0243
# Epoch 268/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 0.0097 - val_loss: 0.0247
# Epoch 269/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0098 - val_loss: 0.0247
# Epoch 270/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0096 - val_loss: 0.0244
# Epoch 271/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0098 - val_loss: 0.0240
# Epoch 272/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0096 - val_loss: 0.0237
# Epoch 273/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0096 - val_loss: 0.0236
# Epoch 274/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0097 - val_loss: 0.0258
# Epoch 275/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0095 - val_loss: 0.0237
# Epoch 276/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0096 - val_loss: 0.0241
# Epoch 277/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0097 - val_loss: 0.0236
# Epoch 278/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0096 - val_loss: 0.0244
# Epoch 279/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0097 - val_loss: 0.0243
# Epoch 280/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0095 - val_loss: 0.0236
# Epoch 281/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0095 - val_loss: 0.0241
# Epoch 282/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0097 - val_loss: 0.0242
# Epoch 283/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0095 - val_loss: 0.0242
# Epoch 284/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0096 - val_loss: 0.0243
# Epoch 285/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0096 - val_loss: 0.0241
# Epoch 286/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0096 - val_loss: 0.0239
# Epoch 287/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0094 - val_loss: 0.0240
# Epoch 288/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0093 - val_loss: 0.0234
# Epoch 289/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0095 - val_loss: 0.0238
# Epoch 290/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0093 - val_loss: 0.0238
# Epoch 291/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0094 - val_loss: 0.0237
# Epoch 292/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0100 - val_loss: 0.0244
# Epoch 293/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0103 - val_loss: 0.0236
# Epoch 294/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0094 - val_loss: 0.0235
# Epoch 295/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0092 - val_loss: 0.0246
# Epoch 296/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0098 - val_loss: 0.0235
# Epoch 297/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0102 - val_loss: 0.0237
# Epoch 298/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0094 - val_loss: 0.0235
# Epoch 299/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0094 - val_loss: 0.0238
# Epoch 300/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0092 - val_loss: 0.0236
# Epoch 301/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0093 - val_loss: 0.0252
# Epoch 302/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0098 - val_loss: 0.0239
# Epoch 303/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0092 - val_loss: 0.0238
# Epoch 304/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0093 - val_loss: 0.0238
# Epoch 305/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0093 - val_loss: 0.0239
# Epoch 306/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0091 - val_loss: 0.0239
# Epoch 307/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0092 - val_loss: 0.0241
# Epoch 308/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0094 - val_loss: 0.0239
# Epoch 309/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0092 - val_loss: 0.0241
# Epoch 310/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0093 - val_loss: 0.0235
# Epoch 311/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0092 - val_loss: 0.0236
# Epoch 312/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0091 - val_loss: 0.0245
# Epoch 313/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0099 - val_loss: 0.0232
# Epoch 314/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0093 - val_loss: 0.0240
# Epoch 315/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0099 - val_loss: 0.0230
# Epoch 316/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0092 - val_loss: 0.0229
# Epoch 317/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0103 - val_loss: 0.0244
# Epoch 318/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0091 - val_loss: 0.0241
# Epoch 319/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0091 - val_loss: 0.0234
# Epoch 320/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0090 - val_loss: 0.0236
# Epoch 321/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - loss: 0.0090 - val_loss: 0.0235
# Epoch 322/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0090 - val_loss: 0.0239
# Epoch 323/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0090 - val_loss: 0.0231
# Epoch 324/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0091 - val_loss: 0.0239
# Epoch 325/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0090 - val_loss: 0.0238
# Epoch 326/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0090 - val_loss: 0.0237
# Epoch 327/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0090 - val_loss: 0.0242
# Epoch 328/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 0.0092 - val_loss: 0.0238
# Epoch 329/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0091 - val_loss: 0.0245
# Epoch 330/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - loss: 0.0090 - val_loss: 0.0238
# Epoch 331/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - loss: 0.0092 - val_loss: 0.0239
# Epoch 332/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0090 - val_loss: 0.0241
# Epoch 333/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0091 - val_loss: 0.0234
# Epoch 334/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0091 - val_loss: 0.0240
# Epoch 335/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0088 - val_loss: 0.0239
# Epoch 336/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0090 - val_loss: 0.0239
# Epoch 337/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0089 - val_loss: 0.0245
# Epoch 338/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0104 - val_loss: 0.0240
# Epoch 339/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0096 - val_loss: 0.0238
# Epoch 340/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0088 - val_loss: 0.0239
# Epoch 341/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0088 - val_loss: 0.0239
# Epoch 342/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0089 - val_loss: 0.0237
# Epoch 343/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0087 - val_loss: 0.0239
# Epoch 344/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0089 - val_loss: 0.0230
# Epoch 345/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0094 - val_loss: 0.0238
# Epoch 346/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0091 - val_loss: 0.0239
# Epoch 347/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0094 - val_loss: 0.0233
# Epoch 348/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0088 - val_loss: 0.0241
# Epoch 349/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0088 - val_loss: 0.0241
# Epoch 350/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0088 - val_loss: 0.0234
# Epoch 351/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0088 - val_loss: 0.0243
# Epoch 352/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0088 - val_loss: 0.0237
# Epoch 353/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0088 - val_loss: 0.0231
# Epoch 354/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0087 - val_loss: 0.0233
# Epoch 355/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0088 - val_loss: 0.0237
# Epoch 356/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0088 - val_loss: 0.0232
# Epoch 357/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - loss: 0.0088 - val_loss: 0.0238
# Epoch 358/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0089 - val_loss: 0.0234
# Epoch 359/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0089 - val_loss: 0.0241
# Epoch 360/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0092 - val_loss: 0.0242
# Epoch 361/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0088 - val_loss: 0.0231
# Epoch 362/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0088 - val_loss: 0.0236
# Epoch 363/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0087 - val_loss: 0.0234
# Epoch 364/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0088 - val_loss: 0.0236
# Epoch 365/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0091 - val_loss: 0.0239
# Epoch 366/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0086 - val_loss: 0.0237
# Epoch 367/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0092 - val_loss: 0.0234
# Epoch 368/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0086 - val_loss: 0.0239
# Epoch 369/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0087 - val_loss: 0.0241
# Epoch 370/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 0.0088 - val_loss: 0.0232
# Epoch 371/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0095 - val_loss: 0.0236
# Epoch 372/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0088 - val_loss: 0.0234
# Epoch 373/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0087 - val_loss: 0.0240
# Epoch 374/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0085 - val_loss: 0.0235
# Epoch 375/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0086 - val_loss: 0.0240
# Epoch 376/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0087 - val_loss: 0.0235
# Epoch 377/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0089 - val_loss: 0.0239
# Epoch 378/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0087 - val_loss: 0.0242
# Epoch 379/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0092 - val_loss: 0.0245
# Epoch 380/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0088 - val_loss: 0.0239
# Epoch 381/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0088 - val_loss: 0.0240
# Epoch 382/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0086 - val_loss: 0.0246
# Epoch 383/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0093 - val_loss: 0.0237
# Epoch 384/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0086 - val_loss: 0.0234
# Epoch 385/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0086 - val_loss: 0.0239
# Epoch 386/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0087 - val_loss: 0.0236
# Epoch 387/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0085 - val_loss: 0.0240
# Epoch 388/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0086 - val_loss: 0.0230
# Epoch 389/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0086 - val_loss: 0.0234
# Epoch 390/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0086 - val_loss: 0.0235
# Epoch 391/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0085 - val_loss: 0.0235
# Epoch 392/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0086 - val_loss: 0.0238
# Epoch 393/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0086 - val_loss: 0.0239
# Epoch 394/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0087 - val_loss: 0.0239
# Epoch 395/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - loss: 0.0086 - val_loss: 0.0232
# Epoch 396/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0086 - val_loss: 0.0231
# Epoch 397/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0084 - val_loss: 0.0235
# Epoch 398/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0088 - val_loss: 0.0228
# Epoch 399/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0085 - val_loss: 0.0234
# Epoch 400/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0085 - val_loss: 0.0233
# Epoch 401/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0086 - val_loss: 0.0234
# Epoch 402/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0085 - val_loss: 0.0232
# Epoch 403/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0083 - val_loss: 0.0235
# Epoch 404/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 0.0085 - val_loss: 0.0234
# Epoch 405/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0085 - val_loss: 0.0239
# Epoch 406/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - loss: 0.0092 - val_loss: 0.0229
# Epoch 407/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0085 - val_loss: 0.0236
# Epoch 408/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0087 - val_loss: 0.0232
# Epoch 409/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - loss: 0.0084 - val_loss: 0.0233
# Epoch 410/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - loss: 0.0085 - val_loss: 0.0232
# Epoch 411/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - loss: 0.0091 - val_loss: 0.0232
# Epoch 412/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - loss: 0.0085 - val_loss: 0.0234
# Epoch 413/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - loss: 0.0085 - val_loss: 0.0230
# Epoch 414/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - loss: 0.0087 - val_loss: 0.0226
# Epoch 415/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - loss: 0.0085 - val_loss: 0.0234
# Epoch 416/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.0084 - val_loss: 0.0249
# Epoch 417/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.0084 - val_loss: 0.0228
# Epoch 418/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - loss: 0.0084 - val_loss: 0.0227
# Epoch 419/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0084 - val_loss: 0.0237
# Epoch 420/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - loss: 0.0087 - val_loss: 0.0235
# Epoch 421/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - loss: 0.0084 - val_loss: 0.0230
# Epoch 422/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - loss: 0.0083 - val_loss: 0.0227
# Epoch 423/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.0084 - val_loss: 0.0235
# Epoch 424/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - loss: 0.0084 - val_loss: 0.0235
# Epoch 425/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0083 - val_loss: 0.0233
# Epoch 426/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - loss: 0.0085 - val_loss: 0.0242
# Epoch 427/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - loss: 0.0085 - val_loss: 0.0232
# Epoch 428/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - loss: 0.0085 - val_loss: 0.0232
# Epoch 429/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 0.0083 - val_loss: 0.0231
# Epoch 430/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0084 - val_loss: 0.0233
# Epoch 431/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0084 - val_loss: 0.0229
# Epoch 432/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0083 - val_loss: 0.0235
# Epoch 433/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0083 - val_loss: 0.0237
# Epoch 434/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0084 - val_loss: 0.0236
# Epoch 435/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0085 - val_loss: 0.0232
# Epoch 436/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0083 - val_loss: 0.0227
# Epoch 437/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - loss: 0.0083 - val_loss: 0.0231
# Epoch 438/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 0.0084 - val_loss: 0.0233
# Epoch 439/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 11s 30ms/step - loss: 0.0086 - val_loss: 0.0239
# Epoch 440/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0085 - val_loss: 0.0235
# Epoch 441/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.0087 - val_loss: 0.0231
# Epoch 442/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0086 - val_loss: 0.0226
# Epoch 443/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0083 - val_loss: 0.0232
# Epoch 444/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - loss: 0.0086 - val_loss: 0.0236
# Epoch 445/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - loss: 0.0082 - val_loss: 0.0235
# Epoch 446/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - loss: 0.0085 - val_loss: 0.0237
# Epoch 447/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.0082 - val_loss: 0.0226
# Epoch 448/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0083 - val_loss: 0.0232
# Epoch 449/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0083 - val_loss: 0.0238
# Epoch 450/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0082 - val_loss: 0.0237
# Epoch 451/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0082 - val_loss: 0.0234
# Epoch 452/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - loss: 0.0082 - val_loss: 0.0241
# Epoch 453/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0084 - val_loss: 0.0237
# Epoch 454/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - loss: 0.0082 - val_loss: 0.0232
# Epoch 455/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 0.0085 - val_loss: 0.0229
# Epoch 456/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - loss: 0.0082 - val_loss: 0.0234
# Epoch 457/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.0081 - val_loss: 0.0236
# Epoch 458/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 0.0082 - val_loss: 0.0239
# Epoch 459/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0083 - val_loss: 0.0234
# Epoch 460/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.0083 - val_loss: 0.0230
# Epoch 461/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0081 - val_loss: 0.0233
# Epoch 462/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0082 - val_loss: 0.0237
# Epoch 463/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0081 - val_loss: 0.0231
# Epoch 464/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 0.0082 - val_loss: 0.0230
# Epoch 465/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0083 - val_loss: 0.0237
# Epoch 466/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0081 - val_loss: 0.0236
# Epoch 467/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0083 - val_loss: 0.0229
# Epoch 468/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0085 - val_loss: 0.0229
# Epoch 469/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0080 - val_loss: 0.0233
# Epoch 470/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0084 - val_loss: 0.0233
# Epoch 471/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0083 - val_loss: 0.0234
# Epoch 472/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0083 - val_loss: 0.0227
# Epoch 473/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0082 - val_loss: 0.0228
# Epoch 474/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0081 - val_loss: 0.0239
# Epoch 475/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0081 - val_loss: 0.0231
# Epoch 476/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.0082 - val_loss: 0.0233
# Epoch 477/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 0.0082 - val_loss: 0.0231
# Epoch 478/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0081 - val_loss: 0.0231
# Epoch 479/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0080 - val_loss: 0.0242
# Epoch 480/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0081 - val_loss: 0.0228
# Epoch 481/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0081 - val_loss: 0.0231
# Epoch 482/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0081 - val_loss: 0.0238
# Epoch 483/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0083 - val_loss: 0.0229
# Epoch 484/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0082 - val_loss: 0.0231
# Epoch 485/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0082 - val_loss: 0.0230
# Epoch 486/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0081 - val_loss: 0.0235
# Epoch 487/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0081 - val_loss: 0.0231
# Epoch 488/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0085 - val_loss: 0.0239
# Epoch 489/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0081 - val_loss: 0.0239
# Epoch 490/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0080 - val_loss: 0.0232
# Epoch 491/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0081 - val_loss: 0.0233
# Epoch 492/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0083 - val_loss: 0.0227
# Epoch 493/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0079 - val_loss: 0.0230
# Epoch 494/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0080 - val_loss: 0.0231
# Epoch 495/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0082 - val_loss: 0.0227
# Epoch 496/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0083 - val_loss: 0.0238
# Epoch 497/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0080 - val_loss: 0.0229
# Epoch 498/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0086 - val_loss: 0.0226
# Epoch 499/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0082 - val_loss: 0.0225
# Epoch 500/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0080 - val_loss: 0.0221
# Epoch 501/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - loss: 0.0080 - val_loss: 0.0229
# Epoch 502/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0080 - val_loss: 0.0230
# Epoch 503/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0081 - val_loss: 0.0233
# Epoch 504/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0081 - val_loss: 0.0226
# Epoch 505/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0082 - val_loss: 0.0227
# Epoch 506/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 0.0090 - val_loss: 0.0234
# Epoch 507/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0082 - val_loss: 0.0231
# ...
# Epoch 531/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0081 - val_loss: 0.0233
# Epoch 532/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0080 - val_loss: 0.0227
# Epoch 533/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0081 - val_loss: 0.0224
# Epoch 534/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0081 - val_loss: 0.0228
# Epoch 535/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0078 - val_loss: 0.0231
# Epoch 536/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0081 - val_loss: 0.0225
# Epoch 537/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0081 - val_loss: 0.0221
# Epoch 538/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0079 - val_loss: 0.0227
# Epoch 539/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0080 - val_loss: 0.0227
# Epoch 540/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0078 - val_loss: 0.0235
# Epoch 541/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0081 - val_loss: 0.0232
# Epoch 542/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0079 - val_loss: 0.0232
# Epoch 543/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0080 - val_loss: 0.0234
# Epoch 544/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0084 - val_loss: 0.0228
# Epoch 545/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0079 - val_loss: 0.0229
# Epoch 546/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0079 - val_loss: 0.0230
# Epoch 547/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0079 - val_loss: 0.0229
# Epoch 548/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0080 - val_loss: 0.0224
# Epoch 549/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0080 - val_loss: 0.0225
# Epoch 550/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0079 - val_loss: 0.0229
# Epoch 551/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0079 - val_loss: 0.0229
# Epoch 552/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0077 - val_loss: 0.0230
# Epoch 553/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0078 - val_loss: 0.0229
# Epoch 554/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0083 - val_loss: 0.0225
# Epoch 555/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0079 - val_loss: 0.0232
# Epoch 556/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0082 - val_loss: 0.0229
# Epoch 557/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0078 - val_loss: 0.0226
# Epoch 558/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0082 - val_loss: 0.0229
# Epoch 559/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0079 - val_loss: 0.0231
# Epoch 560/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0079 - val_loss: 0.0225
# Epoch 561/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0078 - val_loss: 0.0229
# Epoch 562/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0078 - val_loss: 0.0230
# Epoch 563/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0079 - val_loss: 0.0221
# Epoch 564/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0078 - val_loss: 0.0226
# Epoch 565/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0079 - val_loss: 0.0224
# Epoch 566/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0079 - val_loss: 0.0226
# Epoch 567/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0078 - val_loss: 0.0231
# Epoch 568/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0079 - val_loss: 0.0226
# Epoch 569/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0078 - val_loss: 0.0225
# Epoch 570/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0079 - val_loss: 0.0225
# Epoch 571/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0078 - val_loss: 0.0229
# Epoch 572/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0079 - val_loss: 0.0228
# Epoch 573/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0077 - val_loss: 0.0229
# Epoch 574/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0077 - val_loss: 0.0230
# Epoch 575/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0078 - val_loss: 0.0240
# Epoch 576/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0082 - val_loss: 0.0227
# Epoch 577/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0078 - val_loss: 0.0228
# Epoch 578/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0080 - val_loss: 0.0232
# Epoch 579/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0078 - val_loss: 0.0232
# Epoch 580/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0078 - val_loss: 0.0226
# Epoch 581/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0077 - val_loss: 0.0227
# Epoch 582/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0078 - val_loss: 0.0226
# Epoch 583/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0078 - val_loss: 0.0226
# Epoch 584/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.0078 - val_loss: 0.0224
# Epoch 585/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0078 - val_loss: 0.0225
# Epoch 586/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0078 - val_loss: 0.0230
# Epoch 587/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0078 - val_loss: 0.0224
# Epoch 588/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0082 - val_loss: 0.0226
# Epoch 589/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0079 - val_loss: 0.0236
# Epoch 590/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0077 - val_loss: 0.0226
# Epoch 591/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0079 - val_loss: 0.0233
# Epoch 592/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0078 - val_loss: 0.0233
# Epoch 593/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0078 - val_loss: 0.0229
# Epoch 594/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0078 - val_loss: 0.0227
# Epoch 595/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0077 - val_loss: 0.0226
# Epoch 596/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0077 - val_loss: 0.0231
# Epoch 597/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0077 - val_loss: 0.0236
# Epoch 598/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0080 - val_loss: 0.0236
# Epoch 599/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0079 - val_loss: 0.0226
# Epoch 600/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0077 - val_loss: 0.0229
# Epoch 601/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0077 - val_loss: 0.0231
# Epoch 602/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0078 - val_loss: 0.0236
# Epoch 603/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0077 - val_loss: 0.0234
# Epoch 604/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0076 - val_loss: 0.0227
# Epoch 605/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0077 - val_loss: 0.0231
# Epoch 606/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0083 - val_loss: 0.0225
# Epoch 607/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0078 - val_loss: 0.0231
# Epoch 608/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0078 - val_loss: 0.0228
# Epoch 609/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0079 - val_loss: 0.0228
# Epoch 610/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0078 - val_loss: 0.0224
# Epoch 611/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0081 - val_loss: 0.0229
# Epoch 612/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0078 - val_loss: 0.0228
# Epoch 613/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0078 - val_loss: 0.0230
# Epoch 614/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0078 - val_loss: 0.0225
# Epoch 615/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0078 - val_loss: 0.0223
# Epoch 616/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0077 - val_loss: 0.0235
# Epoch 617/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0077 - val_loss: 0.0222
# Epoch 618/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.0076 - val_loss: 0.0227
# Epoch 619/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0078 - val_loss: 0.0223
# Epoch 620/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0076 - val_loss: 0.0222
# Epoch 621/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0077 - val_loss: 0.0224
# Epoch 622/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0076 - val_loss: 0.0224
# Epoch 623/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0077 - val_loss: 0.0232
# Epoch 624/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0078 - val_loss: 0.0225
# Epoch 625/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0077 - val_loss: 0.0225
# Epoch 626/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0077 - val_loss: 0.0228
# Epoch 627/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0078 - val_loss: 0.0227
# Epoch 628/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0077 - val_loss: 0.0221
# Epoch 629/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0077 - val_loss: 0.0228
# Epoch 630/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0077 - val_loss: 0.0227
# Epoch 631/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0077 - val_loss: 0.0225
# Epoch 632/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0078 - val_loss: 0.0226
# Epoch 633/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0080 - val_loss: 0.0226
# Epoch 634/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0077 - val_loss: 0.0220
# Epoch 635/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0076 - val_loss: 0.0226
# Epoch 636/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0081 - val_loss: 0.0225
# Epoch 637/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0076 - val_loss: 0.0221
# Epoch 638/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0076 - val_loss: 0.0223
# Epoch 639/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0076 - val_loss: 0.0223
# Epoch 640/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0076 - val_loss: 0.0231
# Epoch 641/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0076 - val_loss: 0.0228
# Epoch 642/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0076 - val_loss: 0.0222
# Epoch 643/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0075 - val_loss: 0.0225
# Epoch 644/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0076 - val_loss: 0.0229
# Epoch 645/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0076 - val_loss: 0.0224
# Epoch 646/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0077 - val_loss: 0.0227
# Epoch 647/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0077 - val_loss: 0.0224
# Epoch 648/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0077 - val_loss: 0.0230
# Epoch 649/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0077 - val_loss: 0.0221
# Epoch 650/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0076 - val_loss: 0.0229
# Epoch 651/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0077 - val_loss: 0.0228
# Epoch 652/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0076 - val_loss: 0.0223
# Epoch 653/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0076 - val_loss: 0.0222
# Epoch 654/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0078 - val_loss: 0.0223
# Epoch 655/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0076 - val_loss: 0.0230
# Epoch 656/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0076 - val_loss: 0.0234
# Epoch 657/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0077 - val_loss: 0.0220
# Epoch 658/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0077 - val_loss: 0.0222
# Epoch 659/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0076 - val_loss: 0.0226
# Epoch 660/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0077 - val_loss: 0.0221
# Epoch 661/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0076 - val_loss: 0.0224
# Epoch 662/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.0078 - val_loss: 0.0227
# Epoch 663/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0077 - val_loss: 0.0226
# Epoch 664/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - loss: 0.0077 - val_loss: 0.0225
# Epoch 665/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0077 - val_loss: 0.0216
# Epoch 666/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0077 - val_loss: 0.0224
# Epoch 667/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0077 - val_loss: 0.0227
# Epoch 668/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0075 - val_loss: 0.0220
# Epoch 669/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0076 - val_loss: 0.0225
# Epoch 670/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0075 - val_loss: 0.0220
# Epoch 671/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 0.0075 - val_loss: 0.0229
# Epoch 672/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0076 - val_loss: 0.0228
# Epoch 673/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0076 - val_loss: 0.0226
# Epoch 674/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0076 - val_loss: 0.0221
# Epoch 675/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0076 - val_loss: 0.0230
# Epoch 676/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0075 - val_loss: 0.0219
# Epoch 677/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0075 - val_loss: 0.0221
# Epoch 678/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0074 - val_loss: 0.0222
# Epoch 679/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0076 - val_loss: 0.0220
# Epoch 680/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0076 - val_loss: 0.0226
# Epoch 681/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0076 - val_loss: 0.0230
# Epoch 682/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0076 - val_loss: 0.0231
# Epoch 683/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - loss: 0.0075 - val_loss: 0.0229
# Epoch 684/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 0.0077 - val_loss: 0.0224
# Epoch 685/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0077 - val_loss: 0.0225
# Epoch 686/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0076 - val_loss: 0.0223
# Epoch 687/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0077 - val_loss: 0.0224
# Epoch 688/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0077 - val_loss: 0.0225
# Epoch 689/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - loss: 0.0076 - val_loss: 0.0228
# Epoch 690/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 0.0075 - val_loss: 0.0243
# Epoch 691/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0076 - val_loss: 0.0231
# Epoch 692/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0075 - val_loss: 0.0225
# Epoch 693/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0075 - val_loss: 0.0235
# Epoch 694/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 0.0075 - val_loss: 0.0224
# Epoch 695/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0075 - val_loss: 0.0221
# Epoch 696/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 0.0075 - val_loss: 0.0228
# Epoch 697/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0075 - val_loss: 0.0228
# Epoch 698/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 0.0075 - val_loss: 0.0223
# Epoch 699/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0076 - val_loss: 0.0220
# Epoch 700/700
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0076 - val_loss: 0.0221
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# MAE: 11.3179, MSE: 624.1531, R²: 0.7954
#             Y_test       Y_pred        Error  Error_Percent
# count  2152.000000  2152.000000  2152.000000    2152.000000
# mean     39.104704    40.914718    -1.810014      98.104678
# std      55.250420    51.895236    24.923194     318.249651
# min       0.100000    -2.350287  -226.806910       0.000613
# 25%       7.630000    11.898617    -5.344516       7.587801
# 50%      24.390264    27.559562    -0.481010      18.248897
# 75%      41.525000    43.206692     2.948005      49.792422
# max     340.196000   326.874563   269.962861    8587.324798

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score
from tensorflow.keras import Input

import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# === CALLBACK pour suivre les poids ===
class WeightLogger(Callback):
    def __init__(self, layer_name="lstm"):
        super().__init__()
        self.layer_name = layer_name
        self.weights_per_epoch = []

    def on_epoch_end(self, epoch, logs=None):
        for layer in self.model.layers:
            if self.layer_name in layer.name.lower():
                weights = layer.get_weights()[0]
                self.weights_per_epoch.append(weights.copy())
                break

# === 1. Chargement des données ===
def load_data(csv_path, ws):
    df = pd.read_csv(csv_path, sep=';')
    df['date1'] = pd.to_datetime(df['date'], dayfirst=True)

    df['dayofweek'] = df['date1'].dt.dayofweek
    df['month'] = df['date1'].dt.month

    df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
    df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)
    df['dayofweek_sin'] = np.sin(2 * np.pi * df['dayofweek'] / 7)
    df['dayofweek_cos'] = np.cos(2 * np.pi * df['dayofweek'] / 7)

    df.drop(columns=['month', 'dayofweek'], inplace=True)
    df = df.select_dtypes(include=[np.number])
    scaler = MinMaxScaler()
    scaled_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
    y_scaled = scaled_df['production']
    X_scaled = scaled_df.drop(columns=['production'])

    def create_sequences(X, y, window_size=21):
        Xs, ys = [], []
        for i in range(len(X) - window_size):
            Xs.append(X[i:i + window_size])
            ys.append(y[i + window_size])
        return np.array(Xs), np.array(ys)

    X_seq, y_seq = create_sequences(X_scaled, y_scaled, ws)
    return X_seq, y_seq, scaler, scaled_df

# === 2. Model ConvLSTM1D ===
def model_convlstm1d(X_seq, y_seq, epoch, batch_sizes):
    X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42)

    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])),
        Conv1D(filters=128, kernel_size=5, activation='relu', padding='same'),
        LSTM(64, return_sequences=False),
        Dense(32, activation='relu'),
        Dense(1)
    ])
    model.compile(optimizer=Adam(0.001), loss='mae')

    weight_logger = WeightLogger(layer_name="lstm")

    history = model.fit(
        X_train, y_train,
        epochs=epoch,
        batch_size=batch_sizes,
        validation_split=0.1,
        verbose=1,
        callbacks=[weight_logger]
    )

    y_pred = model.predict(X_test).flatten()

    return model, history, y_pred, y_test, weight_logger

# === 3. Performance model ===
def plot_function(scaled_data, y_pred, y_test, scaler, weight_logger, history):
    n_features = scaled_data.shape[1]
    dummy = np.zeros((len(y_pred), n_features))
    target_idx = scaled_data.columns.get_loc('production')
    dummy[:, target_idx] = y_pred
    y_pred_real = scaler.inverse_transform(dummy)[:, target_idx]

    dummy_test = np.zeros((len(y_test), n_features))
    dummy_test[:, target_idx] = y_test
    y_test_real = scaler.inverse_transform(dummy_test)[:, target_idx]

    mae = mean_absolute_error(y_test_real, y_pred_real)
    mse = np.mean((y_test_real - y_pred_real) ** 2)
    r2 = r2_score(y_test_real, y_pred_real)

    w00 = [w[0, 0] for w in weight_logger.weights_per_epoch]
    plt.figure(figsize=(8, 4))
    plt.plot(w00)
    plt.xlabel("Époque")
    plt.ylabel("Valeur du poids [0,0]")
    plt.title("Évolution du poids (entrée 0 → cellule 0) dans la couche LSTM")
    plt.grid(True)
    plt.show()

    plt.figure(figsize=(10, 4))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Courbe de Loss (MAE) par époque')
    plt.xlabel('Époque')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(10, 6))
    plt.plot(y_test_real, label="Vrai")
    plt.plot(y_pred_real, label="Prévu")
    plt.legend()
    plt.title(f"Conv1D + LSTM - MAE: {mae:.4f} | R²: {r2:.4f} | MSE: {mse:.4f}")
    plt.show()

    plt.figure(figsize=(6, 6))
    plt.scatter(y_test_real, y_pred_real, alpha=0.7, color='orange')
    plt.plot([min(y_test_real), max(y_test_real)], [min(y_test_real), max(y_test_real)], 'r--', label="Idéal (y = ŷ)")
    plt.xlabel("Valeurs réelles (y)")
    plt.ylabel("Prédictions (ŷ)")
    plt.title("Prédictions vs Réel")
    plt.legend()
    plt.grid(True)
    plt.show()

    return mae, mse, r2, y_test_real, y_pred_real

# === 4. Main ===
def main():
    csv_path = "full_dataset.csv"
    window_size = 21
    X_seq, y_seq, scaler, scaled_data = load_data(csv_path, window_size)
    model, history, y_pred, y_test, weight_logger = model_convlstm1d(X_seq, y_seq, epoch=700, batch_sizes=32)
    mae, mse, r2, y_test_real, y_pred_real = plot_function(scaled_data, y_pred, y_test, scaler, weight_logger, history)
    print(f"MAE: {mae:.4f}, MSE: {mse:.4f}, R²: {r2:.4f}")

    error_percent = np.divide(
        np.abs(y_test_real - y_pred_real),
        y_test_real,
        out=np.full_like(y_test_real, np.nan),
        where=y_test_real != 0
    ) * 100

    StatsDf = pd.DataFrame({
        "Y_test": y_test_real,
        "Y_pred": y_pred_real,
        "Error": y_test_real - y_pred_real,
        "Error_Percent": error_percent
    })

    print(StatsDf.describe())
    StatsDf['Error'].hist(bins=100)
    plt.title("Distribution de l'erreur")
    plt.xlabel("Erreur absolue")
    plt.ylabel("Fréquence")
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Epoch 1/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0485 - val_loss: 0.0472
# Epoch 2/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0352 - val_loss: 0.0394
# Epoch 3/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0334 - val_loss: 0.0354
# Epoch 4/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0335 - val_loss: 0.0352
# Epoch 5/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0323 - val_loss: 0.0420
# Epoch 6/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0329 - val_loss: 0.0352
# Epoch 7/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0315 - val_loss: 0.0347
# Epoch 8/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0319 - val_loss: 0.0333
# Epoch 9/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0315 - val_loss: 0.0342
# Epoch 10/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0312 - val_loss: 0.0396
# Epoch 11/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0309 - val_loss: 0.0326
# Epoch 12/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0301 - val_loss: 0.0327
# Epoch 13/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0301 - val_loss: 0.0337
# Epoch 14/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0293 - val_loss: 0.0331
# Epoch 15/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0294 - val_loss: 0.0326
# Epoch 16/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0297 - val_loss: 0.0323
# Epoch 17/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0289 - val_loss: 0.0320
# Epoch 18/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0288 - val_loss: 0.0318
# Epoch 19/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0288 - val_loss: 0.0328
# Epoch 20/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0286 - val_loss: 0.0323
# Epoch 21/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0285 - val_loss: 0.0346
# Epoch 22/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0276 - val_loss: 0.0321
# Epoch 23/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 0.0276 - val_loss: 0.0321
# Epoch 24/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0295 - val_loss: 0.0322
# Epoch 25/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0277 - val_loss: 0.0323
# Epoch 26/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0274 - val_loss: 0.0333
# Epoch 27/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0272 - val_loss: 0.0322
# Epoch 28/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0263 - val_loss: 0.0311
# Epoch 29/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0258 - val_loss: 0.0320
# Epoch 30/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0258 - val_loss: 0.0312
# Epoch 31/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0252 - val_loss: 0.0309
# Epoch 32/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0254 - val_loss: 0.0314
# Epoch 33/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0253 - val_loss: 0.0313
# Epoch 34/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0251 - val_loss: 0.0292
# Epoch 35/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0248 - val_loss: 0.0306
# Epoch 36/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0241 - val_loss: 0.0295
# Epoch 37/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0243 - val_loss: 0.0298
# Epoch 38/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0240 - val_loss: 0.0302
# Epoch 39/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0238 - val_loss: 0.0290
# Epoch 40/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0231 - val_loss: 0.0299
# Epoch 41/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0234 - val_loss: 0.0297
# Epoch 42/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0231 - val_loss: 0.0284
# Epoch 43/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0230 - val_loss: 0.0302
# Epoch 44/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0237 - val_loss: 0.0289
# Epoch 45/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0232 - val_loss: 0.0290
# Epoch 46/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0223 - val_loss: 0.0292
# Epoch 47/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0222 - val_loss: 0.0288
# Epoch 48/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0218 - val_loss: 0.0291
# Epoch 49/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0220 - val_loss: 0.0291
# Epoch 50/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0211 - val_loss: 0.0278
# Epoch 51/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0212 - val_loss: 0.0276
# Epoch 52/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0217 - val_loss: 0.0272
# Epoch 53/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0210 - val_loss: 0.0288
# Epoch 54/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0208 - val_loss: 0.0291
# Epoch 55/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0212 - val_loss: 0.0270
# Epoch 56/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0203 - val_loss: 0.0280
# Epoch 57/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0206 - val_loss: 0.0274
# Epoch 58/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0204 - val_loss: 0.0273
# Epoch 59/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0203 - val_loss: 0.0273
# Epoch 60/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0202 - val_loss: 0.0272
# Epoch 61/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0192 - val_loss: 0.0264
# Epoch 62/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0196 - val_loss: 0.0260
# Epoch 63/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0193 - val_loss: 0.0281
# Epoch 64/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0192 - val_loss: 0.0258
# Epoch 65/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0186 - val_loss: 0.0302
# Epoch 66/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0197 - val_loss: 0.0257
# Epoch 67/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0189 - val_loss: 0.0264
# Epoch 68/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0181 - val_loss: 0.0244
# Epoch 69/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0182 - val_loss: 0.0271
# Epoch 70/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0180 - val_loss: 0.0265
# Epoch 71/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - loss: 0.0179 - val_loss: 0.0251
# Epoch 72/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0179 - val_loss: 0.0255
# Epoch 73/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0177 - val_loss: 0.0252
# Epoch 74/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0176 - val_loss: 0.0253
# Epoch 75/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0174 - val_loss: 0.0239
# Epoch 76/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0172 - val_loss: 0.0250
# Epoch 77/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0166 - val_loss: 0.0248
# Epoch 78/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0178 - val_loss: 0.0251
# Epoch 79/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0168 - val_loss: 0.0273
# Epoch 80/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0168 - val_loss: 0.0252
# Epoch 81/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0161 - val_loss: 0.0245
# Epoch 82/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0165 - val_loss: 0.0238
# Epoch 83/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0164 - val_loss: 0.0238
# Epoch 84/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0165 - val_loss: 0.0252
# Epoch 85/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0161 - val_loss: 0.0254
# Epoch 86/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0158 - val_loss: 0.0242
# Epoch 87/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0161 - val_loss: 0.0245
# Epoch 88/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0161 - val_loss: 0.0235
# Epoch 89/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0160 - val_loss: 0.0251
# Epoch 90/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0156 - val_loss: 0.0240
# Epoch 91/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0153 - val_loss: 0.0246
# Epoch 92/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0155 - val_loss: 0.0242
# Epoch 93/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0152 - val_loss: 0.0233
# Epoch 94/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0151 - val_loss: 0.0240
# Epoch 95/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0153 - val_loss: 0.0248
# Epoch 96/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0153 - val_loss: 0.0234
# Epoch 97/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0153 - val_loss: 0.0236
# Epoch 98/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0152 - val_loss: 0.0241
# Epoch 99/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0150 - val_loss: 0.0228
# Epoch 100/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0150 - val_loss: 0.0239
# Epoch 101/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0147 - val_loss: 0.0231
# Epoch 102/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0144 - val_loss: 0.0235
# Epoch 103/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0147 - val_loss: 0.0226
# Epoch 104/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0145 - val_loss: 0.0228
# Epoch 105/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0142 - val_loss: 0.0229
# Epoch 106/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0145 - val_loss: 0.0237
# Epoch 107/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0147 - val_loss: 0.0246
# Epoch 108/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0143 - val_loss: 0.0233
# Epoch 109/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0139 - val_loss: 0.0225
# Epoch 110/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0139 - val_loss: 0.0234
# Epoch 111/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0141 - val_loss: 0.0237
# Epoch 112/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0142 - val_loss: 0.0242
# Epoch 113/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0140 - val_loss: 0.0232
# Epoch 114/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0137 - val_loss: 0.0227
# Epoch 115/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0144 - val_loss: 0.0225
# Epoch 116/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0136 - val_loss: 0.0235
# Epoch 117/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0136 - val_loss: 0.0241
# Epoch 118/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0134 - val_loss: 0.0231
# Epoch 119/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0137 - val_loss: 0.0226
# Epoch 120/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0133 - val_loss: 0.0226
# Epoch 121/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0135 - val_loss: 0.0226
# Epoch 122/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0130 - val_loss: 0.0226
# Epoch 123/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0136 - val_loss: 0.0230
# Epoch 124/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0132 - val_loss: 0.0239
# Epoch 125/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0131 - val_loss: 0.0236
# Epoch 126/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0132 - val_loss: 0.0228
# Epoch 127/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0131 - val_loss: 0.0233
# Epoch 128/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0132 - val_loss: 0.0236
# Epoch 129/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0131 - val_loss: 0.0226
# Epoch 130/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0133 - val_loss: 0.0226
# Epoch 131/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0126 - val_loss: 0.0223
# Epoch 132/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0129 - val_loss: 0.0221
# Epoch 133/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0125 - val_loss: 0.0228
# Epoch 134/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0125 - val_loss: 0.0215
# Epoch 135/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0126 - val_loss: 0.0230
# Epoch 136/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0129 - val_loss: 0.0231
# Epoch 137/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0124 - val_loss: 0.0222
# Epoch 138/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0128 - val_loss: 0.0224
# Epoch 139/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0129 - val_loss: 0.0229
# Epoch 140/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0125 - val_loss: 0.0242
# Epoch 141/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0124 - val_loss: 0.0231
# Epoch 142/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0125 - val_loss: 0.0230
# Epoch 143/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0126 - val_loss: 0.0215
# Epoch 144/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0122 - val_loss: 0.0231
# Epoch 145/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0125 - val_loss: 0.0227
# Epoch 146/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0123 - val_loss: 0.0217
# Epoch 147/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0123 - val_loss: 0.0224
# Epoch 148/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0121 - val_loss: 0.0220
# Epoch 149/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0121 - val_loss: 0.0234
# Epoch 150/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0121 - val_loss: 0.0226
# Epoch 151/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0120 - val_loss: 0.0234
# Epoch 152/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0119 - val_loss: 0.0219
# Epoch 153/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0120 - val_loss: 0.0217
# Epoch 154/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0117 - val_loss: 0.0219
# Epoch 155/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0120 - val_loss: 0.0221
# Epoch 156/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0124 - val_loss: 0.0219
# Epoch 157/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0122 - val_loss: 0.0225
# Epoch 158/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0120 - val_loss: 0.0218
# Epoch 159/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0121 - val_loss: 0.0224
# Epoch 160/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0117 - val_loss: 0.0223
# Epoch 161/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0119 - val_loss: 0.0222
# Epoch 162/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0119 - val_loss: 0.0216
# Epoch 163/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0117 - val_loss: 0.0229
# Epoch 164/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0115 - val_loss: 0.0219
# Epoch 165/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0117 - val_loss: 0.0217
# Epoch 166/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0117 - val_loss: 0.0208
# Epoch 167/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0115 - val_loss: 0.0225
# Epoch 168/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0116 - val_loss: 0.0230
# Epoch 169/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0115 - val_loss: 0.0212
# Epoch 170/700
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0115 - val_loss: 0.0224
# Epoch 171/700
#   7/245 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0134
